# %%
import pandas as pd

# %%
df_reviews = pd.read_json('/content/reviews_data_v3.json', lines=True)
print(df_reviews)
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54406  2957480        1790600         176756097      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually! Just like a little factor...     positive
# ...

# %%
print(df_reviews.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54411 entries, 0 to 54410
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   app_id                       54411 non-null  int64
#  1   parent_app_id                54411 non-null  int64
#  2   recommendationid             54411 non-null  int64
#  3   recommendation               54411 non-null  object
#  4   review_text                  54411 non-null  object
#  5   review_score                 54411 non-null  object
#  6   total_playtime_hours         54411 non-null  float64
#  7   playtime_at_review_hours     54411 non-null  float64
#  8   votes_up                     54411 non-null  int64
#  9   steam_purchase               54411 non-null  bool
#  10  received_for_free            54411 non-null  bool
#  11  written_during_early_access  54411 non-null  bool
# dtypes: bool(3), float64(2), int64(4), object(3)
# ...

# %%
df_reviews.duplicated(subset=['review_text'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54405    False
# 54407    False
# 54408    False
# 54409    False
# 54410    False
# Length: 53678, dtype: bool

# %%
df_reviews.drop_duplicates(subset=['review_text'],inplace=True)

# %%
df_reviews.duplicated(subset=['review_text'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49503    False
# 49504    False
# 49505    False
# 49506    False
# 49507    False
# Length: 48106, dtype: bool

# %%
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually! Just like a little factor...     positive
# ...

# %%
import re


df_reviews['review_text'] = df_reviews['review_text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# %%
df_reviews
# Out:
#         app_id  parent_app_id recommendation  \
# 0      2183900        2183900    Recommended
# 1      2183900        2183900    Recommended
# 2      2183900        2183900    Recommended
# 3      2183900        2183900    Recommended
# 4      2183900        2183900    Recommended
# ...        ...            ...            ...
# 49503  3959440        2634950    Recommended
# 49504  3959440        2634950    Recommended
# 49505  3959440        2634950    Recommended
# 49506  3959440        2634950    Recommended
# 49507  2419810        1435790    Recommended
#
#                                              review_text review_score  \
# 0      with friends peak \r\nwithout friends peak \r\...     positive
# 1      h2b10 Hours of Pure Testosteronebh2\n\nI went ...     positive
# 2      h3 Warning Can be quite addictive h3\r\nbiFor ...     positive
# 3      Tthe scale of it was impressive It really puts...     positive
# ...

# %%
df_reviews['review_text'] = df_reviews['review_text'].str.replace(r'\r\n', ' ', regex=True)

# %%
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually Just like a little factori...     positive
# ...

# %%
df_reviews['review_text'] = df_reviews['review_text'].str.replace(r'\n\n', ' ', regex=True)

# %%
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually Just like a little factori...     positive
# ...

# %%
df_reviews.loc[200,'review_text']
# Out:
# 'bTLDR  Great Anime Metroidvania of 2026 Dont forget your controller Have funb h1Prosh1 listCharacter designs are great Beautiful soundtracks Combats are very satisfying and addictive bKotama is so cuteb Seriously one of the reasons I bought this game was because of that thumbnail alonelist h1Consh1 listI wished the game were fully voiceacted If that feature ever comes I would definitely go back and play the whole game againlist'

# %%
df_reviews['review_text'] = df_reviews['review_text'].str.replace(r'\n', ' ', regex=True)
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually Just like a little factori...     positive
# ...

# %%
df_reviews.duplicated(subset=['review_text'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54405    False
# 54407    False
# 54408    False
# 54409    False
# 54410    False
# Length: 53678, dtype: bool

# %%
df_reviews['review_text'] = df_reviews['review_text'].apply(
    lambda x: re.sub(r'\s+', ' ', str(x))
).str.strip()
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually Just like a little factori...     positive
# ...

# %%
df_reviews['review_text'] = df_reviews['review_text'].apply(
    lambda x: re.sub(r'[^\w\s]', '', str(x))
)
df_reviews
# Out:
#         app_id  parent_app_id  recommendationid   recommendation  \
# 0      3669570        3669570         223875804      Recommended
# 1      3669570        3669570         219038522      Recommended
# 2      3669570        3669570         223815953      Recommended
# 3      3669570        3669570         223710270  Not Recommended
# 4      3669570        3669570         223641705      Recommended
# ...        ...            ...               ...              ...
# 54405  2957480        1790600         176774972      Recommended
# 54407  2957480        1790600         176727297  Not Recommended
# 54408  2957480        1790600         176724096  Not Recommended
# 54409  2957480        1790600         176716020      Recommended
# 54410  2957480        1790600         176697534  Not Recommended
#
#                                              review_text review_score  \
# 0      Really fun actually Just like a little factori...     positive
# ...

# %%
df_reviews.duplicated(subset=['review_text'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54405    False
# 54407    False
# 54408    False
# 54409    False
# 54410    False
# Length: 53489, dtype: bool

# %%
df_reviews.drop_duplicates(subset=['review_text'],inplace=True)

# %%
df_reviews.to_json('reviews_data_cleaned.json', orient='records', lines=True)

print("Data successfully cleaned and saved to 'games_data_cleaned.json'!")
# Out:
# Data successfully cleaned and saved to 'games_data_cleaned.json'!

# %%
df_reviews
# Out:
#         app_id  parent_app_id recommendation  \
# 0      2183900        2183900    Recommended
# 1      2183900        2183900    Recommended
# 2      2183900        2183900    Recommended
# 3      2183900        2183900    Recommended
# 4      2183900        2183900    Recommended
# ...        ...            ...            ...
# 49502  3959440        2634950    Recommended
# 49504  3959440        2634950    Recommended
# 49505  3959440        2634950    Recommended
# 49506  3959440        2634950    Recommended
# 49507  2419810        1435790    Recommended
#
#                                              review_text review_score  \
# 0      with friends peak without friends peak the gam...     positive
# 1      h2b10 Hours of Pure Testosteronebh2 I went int...     positive
# 2      h3 Warning Can be quite addictive h3 biFor The...     positive
# 3      Tthe scale of it was impressive It really puts...     positive
# ...
